# %% [markdown]
# ### Classification of pH range using machine learning

# %%
#libs
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn import linear_model
import pandas as pd
import numpy as np
import scikitplot as skplt
import matplotlib.pyplot as plt
from sklearn import metrics

from sklearn.pipeline import Pipeline
from sklearn import preprocessing as pp

# %%
# load data
acidoCEST_ML = pd.read_parquet('../clean_data/acido_CEST_MRI_Iopamidol.parquet.gzip')

# drop columns we cannot measure or that are redundant
cols_2_drop = ['ApproT1(sec)','Temp','ExpB0(ppm)','FILE','Conc(mM)']
acidoCEST_ML = acidoCEST_ML.drop(cols_2_drop, axis = 1)

# %%
# define experimental columns -- > things we measure other than CEST
exper_cols = [ 'ExpB1(percent)', 'ExpB0(Hz)', 'SatPower(uT)',  'SatTime(ms)','ExpT1(ms)', 'ExpT2(ms)']

# %%
s = [x for x in acidoCEST_ML.shape]
print( f'data size | rows = {s[0]:,}, cols = {s[1]:,}' )
# Out:
# data size | rows = 20,000, cols = 88

# %%
# used during development
#acidoCEST_ML  = acidoCEST_ML.sample(frac=.10)

# %% [markdown]
# ## Functions

# %%
# Logistic Regression
from sklearn.metrics import confusion_matrix, classification_report

def classification_metrics(Yexpected, Yhat):
    cm = confusion_matrix(Yexpected, Yhat)
    TN, FP, FN, TP = list(cm.flatten())
    
    metrics = dict (  PPV =  TP / (TP + FP) 
                 , NPV = TN / (TN + FN)
                 , SEN = TP / (TP + FN)
                 , SPC = TN / (TN + FP)
               )
    for m in metrics.keys():
        metrics[m] = np.round(metrics[m],3)
    
    return metrics

def train_logistic_reg(Xdata, pH_observed, pH_cut_off = 7.0, n_cs = 20, maxC = 1):
    
    # cut off > pH
    y = 1*(pH_observed > pH_cut_off)
    # X data
    X = Xdata.copy()
        
    # Logistic
    logistic = linear_model.LogisticRegression(solver='saga', penalty='l1', max_iter=5000,random_state=42, n_jobs=-1)

    #pipeline
    pipe = Pipeline(steps=[('Scaler', pp.StandardScaler()), ('logistic', logistic)])


    # Training parameters
    Cs = np.logspace(-3, maxC, n_cs)
    
    param_grid ={
    'logistic__C': Cs,
    'logistic__class_weight': ['balanced',None]
    }
    
    
    estimator = GridSearchCV(pipe, param_grid, verbose = 3, cv = 3, n_jobs= 2, scoring=metrics.make_scorer( metrics.balanced_accuracy_score))
    
    # Split data
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

    # Grid Search of Model
    estimator.fit(X_train, y_train)
    
    # CLASSIFC
    classification_per = classification_metrics(y_test, estimator.predict(X_test))
    print('Classification Performance \n')
    [print(f'{key} : {value}') for key, value in classification_per.items()]
    print('---'*10)
    #AUC
    y_probas = estimator.predict_proba(X_test)
    skplt.metrics.plot_roc(y_test, y_probas)
    
    #skplt.metrics.plot_confusion_matrix (y_test, estimator.predict(X_test))
    
    plt.show()
    
    #print( metrics.classification_report(y_test, estimator.predict(X_test)) )
    
    

    return estimator.best_estimator_, X_train, X_test, y_train, y_test

# %%
def classify_pH_Log_Reg(X,Y, cut_offs=[6.5,7.0], Ncs= 10):
    ## Logistic REgression: Only Zspectra pH = 7.0
    
    classifiers =dict()
    
    for pH in cut_offs: 
        print('======  pH = {} ====== '.format(pH))
        clf, X_train, X_test, y_train, y_test = train_logistic_reg(X,Y, pH_cut_off = pH, n_cs = Ncs);
        
        classifiers[str(pH)] = clf

    return classifiers

# %% [markdown]
# ### Logistic Regression

# %%
Ncs = 10

# %% [markdown]
# ## 4.2 and 5.6 only

# %%
Xdata_iso = acidoCEST_ML[['4.2','5.6']]
Ydata = acidoCEST_ML.pH

two_freqs = classify_pH_Log_Reg(Xdata_iso,Ydata, cut_offs=[6.5,7.0], Ncs=Ncs)
# Out:
# ======  pH = 6.5 ======
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# Classification Performance
#
# PPV : 0.839
# NPV : 0.32
# SEN : 0.491
# SPC : 0.717
# ------------------------------
# ======  pH = 7.0 ======
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# Classification Performance
#
# PPV : 0.532
# NPV : 0.823
# SEN : 0.573
# SPC : 0.798
# ------------------------------

# %% [markdown]
# ## 4.2 ppm, 5.6 ppm, exp data

# %%
len(['4.2','5.6'] + exper_cols)
# Out:
# 8

# %%
print(exper_cols)
# Out:
# ['ExpB1(percent)', 'ExpB0(Hz)', 'SatPower(uT)', 'SatTime(ms)', 'ExpT1(ms)', 'ExpT2(ms)']

# %%
c = ['4.2','5.6'] + exper_cols

Xdata_iso_and_exp = acidoCEST_ML[c]
Ydata = acidoCEST_ML['pH'].apply(lambda x: np.round(x,1))

two_freqs_and_exp = classify_pH_Log_Reg(Xdata_iso_and_exp,Ydata, cut_offs=[6.5,7.0], Ncs=Ncs)
# Out:
# ======  pH = 6.5 ======
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# Classification Performance
#
# PPV : 0.854
# NPV : 0.458
# SEN : 0.624
# SPC : 0.749
# ------------------------------
# ======  pH = 7.0 ======
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# Classification Performance
#
# PPV : 0.485
# NPV : 0.868
# SEN : 0.648
# SPC : 0.77
# ------------------------------

# %% [markdown]
# # - Only Zspectra

# %%
Xdata = acidoCEST_ML.drop(exper_cols + ['pH'],axis=1)
Ydata = acidoCEST_ML.pH 

only_zspectra = classify_pH_Log_Reg(Xdata,Ydata, cut_offs=[6.5,7.0], Ncs = Ncs)

print( f'{len(Xdata.columns)} frequencies' )
print( f'{len(exper_cols)} exper cols' )
# Out:
# ======  pH = 6.5 ======
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# Classification Performance
#
# PPV : 0.937
# NPV : 0.506
# SEN : 0.72
# SPC : 0.856
# ------------------------------
# ======  pH = 7.0 ======
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# Classification Performance
#
# PPV : 0.618
# NPV : 0.911
# SEN : 0.806
# SPC : 0.8
# ------------------------------
# 81 frequencies
# 6 exper cols

# %% [markdown]
# # -  Zspectra  + exp data

# %%
Xdata = acidoCEST_ML.drop( ['pH'],axis=1) 
Ydata = acidoCEST_ML.pH

all_data = classify_pH_Log_Reg(Xdata,Ydata, cut_offs=[6.5,7.0], Ncs= Ncs)
print( len( list(Xdata.columns) ) )
# Out:
# ======  pH = 6.5 ======
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# Classification Performance
#
# PPV : 0.944
# NPV : 0.513
# SEN : 0.724
# SPC : 0.872
# ------------------------------
# ======  pH = 7.0 ======
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [CV 1/3] END logistic__C=0.001, logistic__class_weight=balanced;, score=0.500 total time=   0.0s
# [CV 3/3] END logistic__C=0.001, logistic__class_weight=balanced;, score=0.500 total time=   0.0s
# [CV 3/3] END logistic__C=0.001, logistic__class_weight=None;, score=0.500 total time=   0.0s
# [CV 2/3] END logistic__C=0.0027825594022071257, logistic__class_weight=balanced;, score=0.585 total time=   0.0s
# [CV 1/3] END logistic__C=0.0027825594022071257, logistic__class_weight=None;, score=0.500 total time=   0.0s
# [CV 3/3] END logistic__C=0.0027825594022071257, logistic__class_weight=None;, score=0.500 total time=   0.0s
# [CV 1/3] END logistic__C=0.007742636826811269, logistic__class_weight=balanced;, score=0.579 total time=   0.0s
# [CV 3/3] END logistic__C=0.007742636826811269, logistic__class_weight=balanced;, score=0.571 total time=   0.0s
# [CV 2/3] END logistic__C=0.007742636826811269, logistic__class_weight=None;, score=0.500 total time=   0.0s
# [CV 3/3] END logistic__C=0.007742636826811269, logistic__class_weight=None;, score=0.500 total time=   0.0s
# [CV 3/3] END logistic__C=0.021544346900318832, logistic__class_weight=balanced;, score=0.599 total time=   0.0s
# [CV 1/3] END logistic__C=0.021544346900318832, logistic__class_weight=None;, score=0.500 total time=   0.0s
# [CV 1/3] END logistic__C=0.05994842503189409, logistic__class_weight=balanced;, score=0.614 total time=   0.0s
# [CV 2/3] END logistic__C=0.05994842503189409, logistic__class_weight=balanced;, score=0.615 total time=   0.0s
# [CV 3/3] END logistic__C=0.05994842503189409, logistic__class_weight=balanced;, score=0.602 total time=   0.0s
# [CV 1/3] END logistic__C=0.05994842503189409, logistic__class_weight=None;, score=0.500 total time=   0.0s
# [CV 3/3] END logistic__C=0.1668100537200059, logistic__class_weight=balanced;, score=0.602 total time=   0.0s
# [CV 1/3] END logistic__C=0.1668100537200059, logistic__class_weight=None;, score=0.500 total time=   0.0s
# [CV 2/3] END logistic__C=0.1668100537200059, logistic__class_weight=None;, score=0.503 total time=   0.0s
# [CV 3/3] END logistic__C=0.1668100537200059, logistic__class_weight=None;, score=0.500 total time=   0.0s
# [CV 2/3] END logistic__C=0.46415888336127775, logistic__class_weight=None;, score=0.505 total time=   0.0s
# [CV 3/3] END logistic__C=0.46415888336127775, logistic__class_weight=None;, score=0.500 total time=   0.0s
# [CV 1/3] END logistic__C=1.2915496650148828, logistic__class_weight=balanced;, score=0.615 total time=   0.0s
# [CV 2/3] END logistic__C=1.2915496650148828, logistic__class_weight=balanced;, score=0.617 total time=   0.0s
# [CV 3/3] END logistic__C=1.2915496650148828, logistic__class_weight=balanced;, score=0.602 total time=   0.0s
# [CV 1/3] END logistic__C=1.2915496650148828, logistic__class_weight=None;, score=0.502 total time=   0.0s
# [CV 2/3] END logistic__C=1.2915496650148828, logistic__class_weight=None;, score=0.505 total time=   0.0s
# [CV 3/3] END logistic__C=1.2915496650148828, logistic__class_weight=None;, score=0.501 total time=   0.0s
# [CV 3/3] END logistic__C=10.0, logistic__class_weight=balanced;, score=0.602 total time=   0.0s
# [CV 2/3] END logistic__C=10.0, logistic__class_weight=None;, score=0.505 total time=   0.0s
# [CV 1/3] END logistic__C=0.001, logistic__class_weight=balanced;, score=0.500 total time=   0.0s
# [CV 3/3] END logistic__C=0.001, logistic__class_weight=balanced;, score=0.500 total time=   0.0s
# [CV 2/3] END logistic__C=0.001, logistic__class_weight=None;, score=0.500 total time=   0.0s
# [CV 3/3] END logistic__C=0.001, logistic__class_weight=None;, score=0.500 total time=   0.0s
# [CV 3/3] END logistic__C=0.0027825594022071257, logistic__class_weight=balanced;, score=0.567 total time=   0.0s
# [CV 1/3] END logistic__C=0.0027825594022071257, logistic__class_weight=None;, score=0.504 total time=   0.0s
# [CV 1/3] END logistic__C=0.007742636826811269, logistic__class_weight=balanced;, score=0.682 total time=   0.0s
# [CV 2/3] END logistic__C=0.007742636826811269, logistic__class_weight=balanced;, score=0.678 total time=   0.0s
# [CV 3/3] END logistic__C=0.007742636826811269, logistic__class_weight=balanced;, score=0.681 total time=   0.0s
# [CV 1/3] END logistic__C=0.007742636826811269, logistic__class_weight=None;, score=0.567 total time=   0.0s
# [CV 3/3] END logistic__C=0.021544346900318832, logistic__class_weight=balanced;, score=0.687 total time=   0.0s
# [CV 1/3] END logistic__C=0.021544346900318832, logistic__class_weight=None;, score=0.598 total time=   0.0s
# [CV 2/3] END logistic__C=0.021544346900318832, logistic__class_weight=None;, score=0.590 total time=   0.0s
# [CV 3/3] END logistic__C=0.021544346900318832, logistic__class_weight=None;, score=0.596 total time=   0.0s
# [CV 2/3] END logistic__C=0.05994842503189409, logistic__class_weight=None;, score=0.607 total time=   0.0s
# [CV 3/3] END logistic__C=0.05994842503189409, logistic__class_weight=None;, score=0.610 total time=   0.0s
# [CV 1/3] END logistic__C=0.1668100537200059, logistic__class_weight=balanced;, score=0.696 total time=   0.0s
# [CV 2/3] END logistic__C=0.1668100537200059, logistic__class_weight=balanced;, score=0.689 total time=   0.0s
# [CV 3/3] END logistic__C=0.1668100537200059, logistic__class_weight=balanced;, score=0.689 total time=   0.0s
# [CV 1/3] END logistic__C=0.1668100537200059, logistic__class_weight=None;, score=0.614 total time=   0.0s
# [CV 2/3] END logistic__C=0.1668100537200059, logistic__class_weight=None;, score=0.613 total time=   0.0s
# [CV 3/3] END logistic__C=0.1668100537200059, logistic__class_weight=None;, score=0.618 total time=   0.0s
# [CV 3/3] END logistic__C=1.2915496650148828, logistic__class_weight=balanced;, score=0.689 total time=   0.0s
# [CV 1/3] END logistic__C=1.2915496650148828, logistic__class_weight=None;, score=0.617 total time=   0.0s
# [CV 2/3] END logistic__C=1.2915496650148828, logistic__class_weight=None;, score=0.615 total time=   0.0s
# [CV 3/3] END logistic__C=1.2915496650148828, logistic__class_weight=None;, score=0.623 total time=   0.0s
# [CV 1/3] END logistic__C=3.593813663804626, logistic__class_weight=balanced;, score=0.696 total time=   0.0s
# [CV 2/3] END logistic__C=3.593813663804626, logistic__class_weight=balanced;, score=0.689 total time=   0.0s
# [CV 3/3] END logistic__C=3.593813663804626, logistic__class_weight=balanced;, score=0.689 total time=   0.0s
# [CV 1/3] END logistic__C=3.593813663804626, logistic__class_weight=None;, score=0.617 total time=   0.0s
# [CV 1/3] END logistic__C=0.001, logistic__class_weight=balanced;, score=0.500 total time=   0.0s
# [CV 3/3] END logistic__C=0.001, logistic__class_weight=balanced;, score=0.500 total time=   0.0s
# [CV 2/3] END logistic__C=0.001, logistic__class_weight=None;, score=0.500 total time=   0.0s
# [CV 3/3] END logistic__C=0.001, logistic__class_weight=None;, score=0.500 total time=   0.0s
# [CV 3/3] END logistic__C=0.0027825594022071257, logistic__class_weight=balanced;, score=0.594 total time=   0.0s
# [CV 1/3] END logistic__C=0.0027825594022071257, logistic__class_weight=None;, score=0.500 total time=   0.0s
# [CV 1/3] END logistic__C=0.007742636826811269, logistic__class_weight=balanced;, score=0.643 total time=   0.0s
# [CV 2/3] END logistic__C=0.007742636826811269, logistic__class_weight=balanced;, score=0.645 total time=   0.0s
# [CV 3/3] END logistic__C=0.007742636826811269, logistic__class_weight=balanced;, score=0.648 total time=   0.0s
# [CV 1/3] END logistic__C=0.007742636826811269, logistic__class_weight=None;, score=0.507 total time=   0.0s
# [CV 3/3] END logistic__C=0.021544346900318832, logistic__class_weight=balanced;, score=0.692 total time=   0.0s
# [CV 1/3] END logistic__C=0.021544346900318832, logistic__class_weight=None;, score=0.547 total time=   0.0s
# [CV 2/3] END logistic__C=0.021544346900318832, logistic__class_weight=None;, score=0.548 total time=   0.0s
# [CV 3/3] END logistic__C=0.021544346900318832, logistic__class_weight=None;, score=0.550 total time=   0.0s
# [CV 2/3] END logistic__C=0.05994842503189409, logistic__class_weight=None;, score=0.572 total time=   0.1s
# [CV 3/3] END logistic__C=0.05994842503189409, logistic__class_weight=None;, score=0.572 total time=   0.1s
# [CV 1/3] END logistic__C=0.1668100537200059, logistic__class_weight=balanced;, score=0.696 total time=   0.1s
# [CV 2/3] END logistic__C=0.1668100537200059, logistic__class_weight=balanced;, score=0.700 total time=   0.1s
# [CV 1/3] END logistic__C=0.46415888336127775, logistic__class_weight=balanced;, score=0.695 total time=   0.1s
# [CV 2/3] END logistic__C=0.46415888336127775, logistic__class_weight=balanced;, score=0.702 total time=   0.1s
# [CV 3/3] END logistic__C=0.46415888336127775, logistic__class_weight=balanced;, score=0.696 total time=   0.1s
# [CV 1/3] END logistic__C=0.46415888336127775, logistic__class_weight=None;, score=0.583 total time=   0.1s
# [CV 3/3] END logistic__C=1.2915496650148828, logistic__class_weight=balanced;, score=0.696 total time=   0.1s
# [CV 1/3] END logistic__C=1.2915496650148828, logistic__class_weight=None;, score=0.584 total time=   0.1s
# [CV 2/3] END logistic__C=1.2915496650148828, logistic__class_weight=None;, score=0.579 total time=   0.1s
# [CV 3/3] END logistic__C=1.2915496650148828, logistic__class_weight=None;, score=0.596 total time=   0.1s
# [CV 2/3] END logistic__C=3.593813663804626, logistic__class_weight=None;, score=0.580 total time=   0.1s
# [CV 3/3] END logistic__C=3.593813663804626, logistic__class_weight=None;, score=0.595 total time=   0.1s
# [CV 1/3] END logistic__C=10.0, logistic__class_weight=balanced;, score=0.694 total time=   0.1s
# [CV 2/3] END logistic__C=10.0, logistic__class_weight=balanced;, score=0.702 total time=   0.1s
# [CV 1/3] END logistic__C=0.001, logistic__class_weight=balanced;, score=0.604 total time=   0.1s
# [CV 3/3] END logistic__C=0.001, logistic__class_weight=balanced;, score=0.603 total time=   0.1s
# [CV 1/3] END logistic__C=0.0027825594022071257, logistic__class_weight=balanced;, score=0.631 total time=   0.1s
# [CV 2/3] END logistic__C=0.0027825594022071257, logistic__class_weight=balanced;, score=0.626 total time=   0.0s
# [CV 2/3] END logistic__C=0.0027825594022071257, logistic__class_weight=None;, score=0.514 total time=   0.0s
# [CV 3/3] END logistic__C=0.0027825594022071257, logistic__class_weight=None;, score=0.507 total time=   0.0s
# [CV 2/3] END logistic__C=0.007742636826811269, logistic__class_weight=None;, score=0.573 total time=   0.0s
# [CV 3/3] END logistic__C=0.007742636826811269, logistic__class_weight=None;, score=0.575 total time=   0.0s
# [CV 1/3] END logistic__C=0.021544346900318832, logistic__class_weight=balanced;, score=0.724 total time=   0.0s
# [CV 2/3] END logistic__C=0.021544346900318832, logistic__class_weight=balanced;, score=0.720 total time=   0.0s
# [CV 1/3] END logistic__C=0.05994842503189409, logistic__class_weight=balanced;, score=0.724 total time=   0.0s
# [CV 2/3] END logistic__C=0.05994842503189409, logistic__class_weight=balanced;, score=0.722 total time=   0.0s
# [CV 3/3] END logistic__C=0.05994842503189409, logistic__class_weight=balanced;, score=0.731 total time=   0.0s
# [CV 1/3] END logistic__C=0.05994842503189409, logistic__class_weight=None;, score=0.611 total time=   0.0s
# [CV 3/3] END logistic__C=0.1668100537200059, logistic__class_weight=balanced;, score=0.733 total time=   0.0s
# [CV 1/3] END logistic__C=0.1668100537200059, logistic__class_weight=None;, score=0.616 total time=   0.0s
# [CV 2/3] END logistic__C=0.1668100537200059, logistic__class_weight=None;, score=0.614 total time=   0.0s
# [CV 3/3] END logistic__C=0.1668100537200059, logistic__class_weight=None;, score=0.619 total time=   0.0s
# [CV 2/3] END logistic__C=0.46415888336127775, logistic__class_weight=None;, score=0.615 total time=   0.0s
# [CV 3/3] END logistic__C=0.46415888336127775, logistic__class_weight=None;, score=0.622 total time=   0.0s
# [CV 1/3] END logistic__C=1.2915496650148828, logistic__class_weight=balanced;, score=0.724 total time=   0.0s
# [CV 2/3] END logistic__C=1.2915496650148828, logistic__class_weight=balanced;, score=0.723 total time=   0.0s
# [CV 1/3] END logistic__C=3.593813663804626, logistic__class_weight=balanced;, score=0.724 total time=   0.0s
# [CV 2/3] END logistic__C=3.593813663804626, logistic__class_weight=balanced;, score=0.723 total time=   0.0s
# [CV 3/3] END logistic__C=3.593813663804626, logistic__class_weight=balanced;, score=0.732 total time=   0.0s
# [CV 1/3] END logistic__C=3.593813663804626, logistic__class_weight=None;, score=0.617 total time=   0.0s
# [CV 3/3] END logistic__C=10.0, logistic__class_weight=balanced;, score=0.732 total time=   0.0s
# [CV 1/3] END logistic__C=10.0, logistic__class_weight=None;, score=0.617 total time=   0.0s
# [CV 2/3] END logistic__C=10.0, logistic__class_weight=None;, score=0.617 total time=   0.0s
# [CV 3/3] END logistic__C=10.0, logistic__class_weight=None;, score=0.624 total time=   0.0s
# [CV 2/3] END logistic__C=0.001, logistic__class_weight=balanced;, score=0.500 total time=   0.1s
# [CV 1/3] END logistic__C=0.001, logistic__class_weight=None;, score=0.500 total time=   0.1s
# [CV 1/3] END logistic__C=0.0027825594022071257, logistic__class_weight=balanced;, score=0.609 total time=   1.8s
# [CV 2/3] END logistic__C=0.0027825594022071257, logistic__class_weight=balanced;, score=0.624 total time=   1.7s
# [CV 1/3] END logistic__C=0.007742636826811269, logistic__class_weight=balanced;, score=0.727 total time=   6.4s
# [CV 2/3] END logistic__C=0.007742636826811269, logistic__class_weight=balanced;, score=0.728 total time=   5.3s
# [CV 2/3] END logistic__C=0.007742636826811269, logistic__class_weight=None;, score=0.503 total time=   8.0s
# [CV 3/3] END logistic__C=0.007742636826811269, logistic__class_weight=None;, score=0.501 total time=   4.9s
# [CV 3/3] END logistic__C=0.021544346900318832, logistic__class_weight=balanced;, score=0.766 total time=   5.6s
# [CV 2/3] END logistic__C=0.021544346900318832, logistic__class_weight=None;, score=0.564 total time=   7.7s
# [CV 1/3] END logistic__C=0.05994842503189409, logistic__class_weight=balanced;, score=0.787 total time=   7.3s
# [CV 3/3] END logistic__C=0.05994842503189409, logistic__class_weight=balanced;, score=0.783 total time=   7.0s
# [CV 2/3] END logistic__C=0.05994842503189409, logistic__class_weight=None;, score=0.644 total time=   9.0s
# [CV 1/3] END logistic__C=0.1668100537200059, logistic__class_weight=balanced;, score=0.795 total time=   8.8s
# [CV 3/3] END logistic__C=0.1668100537200059, logistic__class_weight=balanced;, score=0.790 total time=   7.8s
# [CV 2/3] END logistic__C=0.1668100537200059, logistic__class_weight=None;, score=0.667 total time=   9.0s
# [CV 1/3] END logistic__C=0.46415888336127775, logistic__class_weight=balanced;, score=0.790 total time=  11.5s
# [CV 3/3] END logistic__C=0.46415888336127775, logistic__class_weight=balanced;, score=0.793 total time=  13.6s
# [CV 2/3] END logistic__C=0.46415888336127775, logistic__class_weight=None;, score=0.679 total time=  17.3s
# [CV 1/3] END logistic__C=1.2915496650148828, logistic__class_weight=balanced;, score=0.790 total time=  17.9s
# [CV 3/3] END logistic__C=1.2915496650148828, logistic__class_weight=balanced;, score=0.794 total time=  15.3s
# [CV 2/3] END logistic__C=1.2915496650148828, logistic__class_weight=None;, score=0.682 total time=  20.9s
# [CV 1/3] END logistic__C=3.593813663804626, logistic__class_weight=balanced;, score=0.790 total time=  19.0s
# [CV 1/3] END logistic__C=3.593813663804626, logistic__class_weight=None;, score=0.681 total time=  19.8s
# [CV 3/3] END logistic__C=3.593813663804626, logistic__class_weight=None;, score=0.698 total time=  18.5s
# [CV 2/3] END logistic__C=10.0, logistic__class_weight=balanced;, score=0.780 total time=  17.2s
# [CV 1/3] END logistic__C=10.0, logistic__class_weight=None;, score=0.680 total time=  21.0s
# [CV 3/3] END logistic__C=10.0, logistic__class_weight=None;, score=0.700 total time=  19.9s
# [CV 2/3] END logistic__C=0.001, logistic__class_weight=balanced;, score=0.500 total time=   0.1s
# [CV 3/3] END logistic__C=0.001, logistic__class_weight=balanced;, score=0.500 total time=   0.1s
# [CV 1/3] END logistic__C=0.0027825594022071257, logistic__class_weight=balanced;, score=0.588 total time=   4.2s
# [CV 2/3] END logistic__C=0.0027825594022071257, logistic__class_weight=balanced;, score=0.584 total time=   2.1s
# [CV 2/3] END logistic__C=0.0027825594022071257, logistic__class_weight=None;, score=0.506 total time=   1.6s
# [CV 2/3] END logistic__C=0.001, logistic__class_weight=balanced;, score=0.500 total time=   0.0s
# [CV 1/3] END logistic__C=0.001, logistic__class_weight=None;, score=0.500 total time=   0.0s
# [CV 2/3] END logistic__C=0.001, logistic__class_weight=None;, score=0.500 total time=   0.0s
# [CV 1/3] END logistic__C=0.0027825594022071257, logistic__class_weight=balanced;, score=0.571 total time=   0.0s
# [CV 3/3] END logistic__C=0.0027825594022071257, logistic__class_weight=balanced;, score=0.564 total time=   0.0s
# [CV 2/3] END logistic__C=0.0027825594022071257, logistic__class_weight=None;, score=0.500 total time=   0.0s
# [CV 2/3] END logistic__C=0.007742636826811269, logistic__class_weight=balanced;, score=0.600 total time=   0.0s
# [CV 1/3] END logistic__C=0.007742636826811269, logistic__class_weight=None;, score=0.500 total time=   0.0s
# [CV 1/3] END logistic__C=0.021544346900318832, logistic__class_weight=balanced;, score=0.617 total time=   0.0s
# [CV 2/3] END logistic__C=0.021544346900318832, logistic__class_weight=balanced;, score=0.614 total time=   0.0s
# [CV 2/3] END logistic__C=0.021544346900318832, logistic__class_weight=None;, score=0.499 total time=   0.0s
# [CV 3/3] END logistic__C=0.021544346900318832, logistic__class_weight=None;, score=0.499 total time=   0.0s
# [CV 2/3] END logistic__C=0.05994842503189409, logistic__class_weight=None;, score=0.502 total time=   0.0s
# [CV 3/3] END logistic__C=0.05994842503189409, logistic__class_weight=None;, score=0.499 total time=   0.0s
# [CV 1/3] END logistic__C=0.1668100537200059, logistic__class_weight=balanced;, score=0.615 total time=   0.0s
# [CV 2/3] END logistic__C=0.1668100537200059, logistic__class_weight=balanced;, score=0.617 total time=   0.0s
# [CV 1/3] END logistic__C=0.46415888336127775, logistic__class_weight=balanced;, score=0.614 total time=   0.0s
# [CV 2/3] END logistic__C=0.46415888336127775, logistic__class_weight=balanced;, score=0.618 total time=   0.0s
# [CV 3/3] END logistic__C=0.46415888336127775, logistic__class_weight=balanced;, score=0.602 total time=   0.0s
# [CV 1/3] END logistic__C=0.46415888336127775, logistic__class_weight=None;, score=0.502 total time=   0.0s
# [CV 1/3] END logistic__C=3.593813663804626, logistic__class_weight=balanced;, score=0.614 total time=   0.0s
# [CV 2/3] END logistic__C=3.593813663804626, logistic__class_weight=balanced;, score=0.617 total time=   0.0s
# [CV 3/3] END logistic__C=3.593813663804626, logistic__class_weight=balanced;, score=0.602 total time=   0.0s
# [CV 1/3] END logistic__C=3.593813663804626, logistic__class_weight=None;, score=0.502 total time=   0.0s
# [CV 2/3] END logistic__C=3.593813663804626, logistic__class_weight=None;, score=0.505 total time=   0.0s
# [CV 3/3] END logistic__C=3.593813663804626, logistic__class_weight=None;, score=0.501 total time=   0.0s
# [CV 1/3] END logistic__C=10.0, logistic__class_weight=balanced;, score=0.614 total time=   0.0s
# [CV 2/3] END logistic__C=10.0, logistic__class_weight=balanced;, score=0.617 total time=   0.0s
# [CV 1/3] END logistic__C=10.0, logistic__class_weight=None;, score=0.502 total time=   0.0s
# [CV 3/3] END logistic__C=10.0, logistic__class_weight=None;, score=0.501 total time=   0.0s
# [CV 2/3] END logistic__C=0.001, logistic__class_weight=balanced;, score=0.500 total time=   0.0s
# [CV 1/3] END logistic__C=0.001, logistic__class_weight=None;, score=0.500 total time=   0.0s
# [CV 1/3] END logistic__C=0.0027825594022071257, logistic__class_weight=balanced;, score=0.566 total time=   0.0s
# [CV 2/3] END logistic__C=0.0027825594022071257, logistic__class_weight=balanced;, score=0.568 total time=   0.0s
# [CV 2/3] END logistic__C=0.0027825594022071257, logistic__class_weight=None;, score=0.505 total time=   0.0s
# [CV 3/3] END logistic__C=0.0027825594022071257, logistic__class_weight=None;, score=0.502 total time=   0.0s
# [CV 2/3] END logistic__C=0.007742636826811269, logistic__class_weight=None;, score=0.567 total time=   0.0s
# [CV 3/3] END logistic__C=0.007742636826811269, logistic__class_weight=None;, score=0.571 total time=   0.0s
# [CV 1/3] END logistic__C=0.021544346900318832, logistic__class_weight=balanced;, score=0.693 total time=   0.0s
# [CV 2/3] END logistic__C=0.021544346900318832, logistic__class_weight=balanced;, score=0.684 total time=   0.0s
# [CV 1/3] END logistic__C=0.05994842503189409, logistic__class_weight=balanced;, score=0.695 total time=   0.0s
# [CV 2/3] END logistic__C=0.05994842503189409, logistic__class_weight=balanced;, score=0.690 total time=   0.0s
# [CV 3/3] END logistic__C=0.05994842503189409, logistic__class_weight=balanced;, score=0.688 total time=   0.0s
# [CV 1/3] END logistic__C=0.05994842503189409, logistic__class_weight=None;, score=0.611 total time=   0.0s
# [CV 1/3] END logistic__C=0.46415888336127775, logistic__class_weight=balanced;, score=0.696 total time=   0.0s
# [CV 2/3] END logistic__C=0.46415888336127775, logistic__class_weight=balanced;, score=0.689 total time=   0.0s
# [CV 3/3] END logistic__C=0.46415888336127775, logistic__class_weight=balanced;, score=0.689 total time=   0.0s
# [CV 1/3] END logistic__C=0.46415888336127775, logistic__class_weight=None;, score=0.617 total time=   0.0s
# [CV 2/3] END logistic__C=0.46415888336127775, logistic__class_weight=None;, score=0.615 total time=   0.0s
# [CV 3/3] END logistic__C=0.46415888336127775, logistic__class_weight=None;, score=0.622 total time=   0.0s
# [CV 1/3] END logistic__C=1.2915496650148828, logistic__class_weight=balanced;, score=0.696 total time=   0.0s
# [CV 2/3] END logistic__C=1.2915496650148828, logistic__class_weight=balanced;, score=0.689 total time=   0.0s
# [CV 2/3] END logistic__C=3.593813663804626, logistic__class_weight=None;, score=0.615 total time=   0.0s
# [CV 3/3] END logistic__C=3.593813663804626, logistic__class_weight=None;, score=0.623 total time=   0.0s
# [CV 1/3] END logistic__C=10.0, logistic__class_weight=balanced;, score=0.696 total time=   0.0s
# [CV 2/3] END logistic__C=10.0, logistic__class_weight=balanced;, score=0.689 total time=   0.0s
# [CV 3/3] END logistic__C=10.0, logistic__class_weight=balanced;, score=0.689 total time=   0.0s
# [CV 1/3] END logistic__C=10.0, logistic__class_weight=None;, score=0.617 total time=   0.0s
# [CV 2/3] END logistic__C=10.0, logistic__class_weight=None;, score=0.615 total time=   0.0s
# [CV 3/3] END logistic__C=10.0, logistic__class_weight=None;, score=0.623 total time=   0.0s
# [CV 2/3] END logistic__C=0.001, logistic__class_weight=balanced;, score=0.500 total time=   0.0s
# [CV 1/3] END logistic__C=0.001, logistic__class_weight=None;, score=0.500 total time=   0.0s
# [CV 1/3] END logistic__C=0.0027825594022071257, logistic__class_weight=balanced;, score=0.605 total time=   0.0s
# [CV 2/3] END logistic__C=0.0027825594022071257, logistic__class_weight=balanced;, score=0.606 total time=   0.0s
# [CV 2/3] END logistic__C=0.0027825594022071257, logistic__class_weight=None;, score=0.500 total time=   0.0s
# [CV 3/3] END logistic__C=0.0027825594022071257, logistic__class_weight=None;, score=0.500 total time=   0.0s
# [CV 2/3] END logistic__C=0.007742636826811269, logistic__class_weight=None;, score=0.508 total time=   0.0s
# [CV 3/3] END logistic__C=0.007742636826811269, logistic__class_weight=None;, score=0.508 total time=   0.0s
# [CV 1/3] END logistic__C=0.021544346900318832, logistic__class_weight=balanced;, score=0.686 total time=   0.0s
# [CV 2/3] END logistic__C=0.021544346900318832, logistic__class_weight=balanced;, score=0.692 total time=   0.0s
# [CV 1/3] END logistic__C=0.05994842503189409, logistic__class_weight=balanced;, score=0.694 total time=   0.1s
# [CV 2/3] END logistic__C=0.05994842503189409, logistic__class_weight=balanced;, score=0.700 total time=   0.1s
# [CV 3/3] END logistic__C=0.05994842503189409, logistic__class_weight=balanced;, score=0.694 total time=   0.1s
# [CV 1/3] END logistic__C=0.05994842503189409, logistic__class_weight=None;, score=0.569 total time=   0.1s
# [CV 3/3] END logistic__C=0.1668100537200059, logistic__class_weight=balanced;, score=0.697 total time=   0.1s
# [CV 1/3] END logistic__C=0.1668100537200059, logistic__class_weight=None;, score=0.580 total time=   0.1s
# [CV 2/3] END logistic__C=0.1668100537200059, logistic__class_weight=None;, score=0.577 total time=   0.1s
# [CV 3/3] END logistic__C=0.1668100537200059, logistic__class_weight=None;, score=0.587 total time=   0.1s
# [CV 2/3] END logistic__C=0.46415888336127775, logistic__class_weight=None;, score=0.579 total time=   0.1s
# [CV 3/3] END logistic__C=0.46415888336127775, logistic__class_weight=None;, score=0.592 total time=   0.1s
# [CV 1/3] END logistic__C=1.2915496650148828, logistic__class_weight=balanced;, score=0.694 total time=   0.1s
# [CV 2/3] END logistic__C=1.2915496650148828, logistic__class_weight=balanced;, score=0.702 total time=   0.1s
# [CV 1/3] END logistic__C=3.593813663804626, logistic__class_weight=balanced;, score=0.694 total time=   0.1s
# [CV 2/3] END logistic__C=3.593813663804626, logistic__class_weight=balanced;, score=0.702 total time=   0.1s
# [CV 3/3] END logistic__C=3.593813663804626, logistic__class_weight=balanced;, score=0.696 total time=   0.1s
# [CV 1/3] END logistic__C=3.593813663804626, logistic__class_weight=None;, score=0.584 total time=   0.1s
# [CV 3/3] END logistic__C=10.0, logistic__class_weight=balanced;, score=0.696 total time=   0.1s
# [CV 1/3] END logistic__C=10.0, logistic__class_weight=None;, score=0.584 total time=   0.1s
# [CV 2/3] END logistic__C=10.0, logistic__class_weight=None;, score=0.580 total time=   0.1s
# [CV 3/3] END logistic__C=10.0, logistic__class_weight=None;, score=0.596 total time=   0.1s
# [CV 2/3] END logistic__C=0.001, logistic__class_weight=balanced;, score=0.608 total time=   0.1s
# [CV 1/3] END logistic__C=0.001, logistic__class_weight=None;, score=0.500 total time=   0.0s
# [CV 2/3] END logistic__C=0.001, logistic__class_weight=None;, score=0.500 total time=   0.0s
# [CV 3/3] END logistic__C=0.001, logistic__class_weight=None;, score=0.500 total time=   0.0s
# [CV 3/3] END logistic__C=0.0027825594022071257, logistic__class_weight=balanced;, score=0.642 total time=   0.0s
# [CV 1/3] END logistic__C=0.0027825594022071257, logistic__class_weight=None;, score=0.507 total time=   0.0s
# [CV 1/3] END logistic__C=0.007742636826811269, logistic__class_weight=balanced;, score=0.706 total time=   0.0s
# [CV 2/3] END logistic__C=0.007742636826811269, logistic__class_weight=balanced;, score=0.705 total time=   0.0s
# [CV 3/3] END logistic__C=0.007742636826811269, logistic__class_weight=balanced;, score=0.715 total time=   0.0s
# [CV 1/3] END logistic__C=0.007742636826811269, logistic__class_weight=None;, score=0.575 total time=   0.0s
# [CV 3/3] END logistic__C=0.021544346900318832, logistic__class_weight=balanced;, score=0.731 total time=   0.0s
# [CV 1/3] END logistic__C=0.021544346900318832, logistic__class_weight=None;, score=0.604 total time=   0.0s
# [CV 2/3] END logistic__C=0.021544346900318832, logistic__class_weight=None;, score=0.605 total time=   0.0s
# [CV 3/3] END logistic__C=0.021544346900318832, logistic__class_weight=None;, score=0.607 total time=   0.0s
# [CV 2/3] END logistic__C=0.05994842503189409, logistic__class_weight=None;, score=0.611 total time=   0.0s
# [CV 3/3] END logistic__C=0.05994842503189409, logistic__class_weight=None;, score=0.614 total time=   0.0s
# [CV 1/3] END logistic__C=0.1668100537200059, logistic__class_weight=balanced;, score=0.724 total time=   0.0s
# [CV 2/3] END logistic__C=0.1668100537200059, logistic__class_weight=balanced;, score=0.724 total time=   0.0s
# [CV 1/3] END logistic__C=0.46415888336127775, logistic__class_weight=balanced;, score=0.724 total time=   0.0s
# [CV 2/3] END logistic__C=0.46415888336127775, logistic__class_weight=balanced;, score=0.724 total time=   0.0s
# [CV 3/3] END logistic__C=0.46415888336127775, logistic__class_weight=balanced;, score=0.732 total time=   0.0s
# [CV 1/3] END logistic__C=0.46415888336127775, logistic__class_weight=None;, score=0.617 total time=   0.0s
# [CV 3/3] END logistic__C=1.2915496650148828, logistic__class_weight=balanced;, score=0.732 total time=   0.0s
# [CV 1/3] END logistic__C=1.2915496650148828, logistic__class_weight=None;, score=0.618 total time=   0.0s
# [CV 2/3] END logistic__C=1.2915496650148828, logistic__class_weight=None;, score=0.616 total time=   0.0s
# [CV 3/3] END logistic__C=1.2915496650148828, logistic__class_weight=None;, score=0.623 total time=   0.0s
# [CV 2/3] END logistic__C=3.593813663804626, logistic__class_weight=None;, score=0.616 total time=   0.0s
# [CV 3/3] END logistic__C=3.593813663804626, logistic__class_weight=None;, score=0.623 total time=   0.0s
# [CV 1/3] END logistic__C=10.0, logistic__class_weight=balanced;, score=0.724 total time=   0.0s
# [CV 2/3] END logistic__C=10.0, logistic__class_weight=balanced;, score=0.723 total time=   0.0s
# [CV 1/3] END logistic__C=0.001, logistic__class_weight=balanced;, score=0.500 total time=   0.1s
# [CV 3/3] END logistic__C=0.001, logistic__class_weight=balanced;, score=0.500 total time=   0.1s
# [CV 2/3] END logistic__C=0.001, logistic__class_weight=None;, score=0.500 total time=   0.1s
# [CV 3/3] END logistic__C=0.001, logistic__class_weight=None;, score=0.500 total time=   0.1s
# [CV 3/3] END logistic__C=0.0027825594022071257, logistic__class_weight=balanced;, score=0.601 total time=   2.4s
# [CV 1/3] END logistic__C=0.0027825594022071257, logistic__class_weight=None;, score=0.500 total time=   0.6s
# [CV 2/3] END logistic__C=0.0027825594022071257, logistic__class_weight=None;, score=0.500 total time=   0.5s
# [CV 3/3] END logistic__C=0.0027825594022071257, logistic__class_weight=None;, score=0.500 total time=   0.7s
# [CV 3/3] END logistic__C=0.007742636826811269, logistic__class_weight=balanced;, score=0.733 total time=   5.2s
# [CV 1/3] END logistic__C=0.007742636826811269, logistic__class_weight=None;, score=0.501 total time=   6.6s
# [CV 1/3] END logistic__C=0.021544346900318832, logistic__class_weight=balanced;, score=0.765 total time=   7.2s
# [CV 2/3] END logistic__C=0.021544346900318832, logistic__class_weight=balanced;, score=0.769 total time=   6.7s
# [CV 1/3] END logistic__C=0.021544346900318832, logistic__class_weight=None;, score=0.560 total time=   6.9s
# [CV 3/3] END logistic__C=0.021544346900318832, logistic__class_weight=None;, score=0.557 total time=   5.9s
# [CV 2/3] END logistic__C=0.05994842503189409, logistic__class_weight=balanced;, score=0.781 total time=   7.2s
# [CV 1/3] END logistic__C=0.05994842503189409, logistic__class_weight=None;, score=0.630 total time=   8.6s
# [CV 3/3] END logistic__C=0.05994842503189409, logistic__class_weight=None;, score=0.641 total time=   7.9s
# [CV 2/3] END logistic__C=0.1668100537200059, logistic__class_weight=balanced;, score=0.783 total time=   8.8s
# [CV 1/3] END logistic__C=0.1668100537200059, logistic__class_weight=None;, score=0.661 total time=   8.7s
# [CV 3/3] END logistic__C=0.1668100537200059, logistic__class_weight=None;, score=0.674 total time=   9.2s
# [CV 2/3] END logistic__C=0.46415888336127775, logistic__class_weight=balanced;, score=0.781 total time=  13.2s
# [CV 1/3] END logistic__C=0.46415888336127775, logistic__class_weight=None;, score=0.675 total time=  13.5s
# [CV 3/3] END logistic__C=0.46415888336127775, logistic__class_weight=None;, score=0.691 total time=  15.5s
# [CV 2/3] END logistic__C=1.2915496650148828, logistic__class_weight=balanced;, score=0.780 total time=  15.3s
# [CV 1/3] END logistic__C=1.2915496650148828, logistic__class_weight=None;, score=0.680 total time=  17.4s
# [CV 3/3] END logistic__C=1.2915496650148828, logistic__class_weight=None;, score=0.696 total time=  18.7s
# [CV 2/3] END logistic__C=3.593813663804626, logistic__class_weight=balanced;, score=0.780 total time=  15.8s
# [CV 3/3] END logistic__C=3.593813663804626, logistic__class_weight=balanced;, score=0.794 total time=  15.3s
# [CV 2/3] END logistic__C=3.593813663804626, logistic__class_weight=None;, score=0.681 total time=  19.9s
# [CV 1/3] END logistic__C=10.0, logistic__class_weight=balanced;, score=0.790 total time=  21.4s
# [CV 3/3] END logistic__C=10.0, logistic__class_weight=balanced;, score=0.793 total time=  16.3s
# [CV 2/3] END logistic__C=10.0, logistic__class_weight=None;, score=0.682 total time=  20.9s
# [CV 1/3] END logistic__C=0.001, logistic__class_weight=balanced;, score=0.500 total time=   0.1s
# [CV 1/3] END logistic__C=0.001, logistic__class_weight=None;, score=0.500 total time=   0.1s
# [CV 2/3] END logistic__C=0.001, logistic__class_weight=None;, score=0.500 total time=   0.1s
# Classification Performance
#
# PPV : 0.64
# NPV : 0.91
# SEN : 0.798
# SPC : 0.82
# ------------------------------
# 87

# %% [markdown]
# ## Coeff

# %%
plt.style.use('tableau-colorblind10')

# %%
coef = all_data['7.0']['logistic'].coef_

C = pd.DataFrame(1-np.exp(coef.reshape(-1,1)),index=acidoCEST_ML.drop( ['pH'],axis=1).columns, columns=['Coeff' ])
print(np.exp(C.head(7)))
_, ax = plt.subplots(dpi=100, figsize=(16,8))
C.plot(kind='bar',ax=ax,rot=90)
plt.title('Logistic Regresson Coefficients for pH cut off = 7.0 \n')
plt.savefig('../figs/Figure_01_Classification.png',bbox_inches='tight')
plt.show()
# Out:
#                    Coeff
# ExpT1(ms)       0.611395
# ExpT2(ms)       1.365669
# ExpB1(percent)  1.103067
# ExpB0(Hz)       0.111837
# SatPower(uT)    1.595702
# SatTime(ms)     1.044235
# -12             0.998826

# %%
coef = all_data['6.5']['logistic'].coef_

C = pd.DataFrame(1-np.exp(coef.reshape(-1,1)),index=acidoCEST_ML.drop( ['pH'],axis=1).columns, columns=['Coeff' ])
print(np.exp(C.head(7)))
_, ax = plt.subplots(dpi=100, figsize=(16,8))
C.plot(kind='bar',ax=ax,rot=90)
plt.title('Logistic Regresson Coefficients for pH cut off = 6.5 \n')

plt.savefig('../figs/Figure_02_Classification.png',bbox_inches='tight')
plt.show()
# Out:
#                    Coeff
# ExpT1(ms)       1.172224
# ExpT2(ms)       0.985150
# ExpB1(percent)  1.020042
# ExpB0(Hz)       0.307338
# SatPower(uT)    0.660087
# SatTime(ms)     1.097723
# -12             0.953750

# %% [markdown]
# ## Feature Selection and Log Reg on selected features

# %%
def select_cols(coefficients):
    d = np.exp(coefficients)
    f= (d >1.90) | (d < 0.10)
    cols = np.array(Xdata.columns.values)
    new_cols = cols[f.reshape(-1,)]

    return new_cols
    
coef1 = all_data['7.0']['logistic'].coef_
coef2 = all_data['6.5']['logistic'].coef_

s1 = set(select_cols(coef1))
s2 = select_cols(coef2)

new_cols = list(s1.union(s2))
new_cols.sort()

print(len(new_cols))

Xdata_small = acidoCEST_ML.drop( ['pH'],axis=1)[new_cols]
Ydata = acidoCEST_ML.pH

all_data_small = classify_pH_Log_Reg(Xdata_small,Ydata, cut_offs=[6.5,7.0], Ncs=Ncs)
# Out:
# 22
# ======  pH = 6.5 ======
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# Classification Performance
#
# PPV : 0.92
# NPV : 0.478
# SEN : 0.702
# SPC : 0.817
# ------------------------------
# ======  pH = 7.0 ======
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# Classification Performance
#
# PPV : 0.574
# NPV : 0.897
# SEN : 0.78
# SPC : 0.768
# ------------------------------

# %%
print(f'The following features were selected: \n {new_cols}')
# Out:
# The following features were selected:
#  ['-1', '-1.2', '-1.4', '0.6', '1', '1.2', '2', '2.4', '2.8', '3.3', '3.4', '4.2', '4.3', '4.4', '5', '5.6', '5.7', '5.8', '5.9', '6', '6.1', 'ExpB0(Hz)']

# %%
# save output
all_data_small_change_in_odds = pd.DataFrame(all_data_small['6.5']['logistic'].coef_.reshape(-1,1),index=new_cols, columns=['6.5'])
all_data_small_change_in_odds['7.0'] = all_data_small['7.0']['logistic'].coef_.reshape(-1,1)
all_data_small_change_in_odds = all_data_small_change_in_odds.applymap(lambda f: np.exp(f) - 1).round(2)
all_data_small_change_in_odds.to_csv('../outputs/classification_change_in_odds_selected.csv')

# %%
#  save pipelines
from joblib import dump, load
dump(all_data_small['6.5'], '../models/pH_classication_pipeline_6p5.joblib') 
dump(all_data_small['7.0'], '../models/pH_classication_pipeline_7p0.joblib')
# Out:
# ['../models/pH_classication_pipeline_7p0.joblib']

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier as RFC

def train_RFC(Spectra, pH_observed, pH_cut_off = 7.0):
    # cut off > pH
    y = 1*(pH_observed > pH_cut_off)
    # X data
    X = Spectra.copy()
        
    # Logistic
    rf = RFC(random_state=42, n_jobs=10)
    
    param_grid ={
    'n_estimators': [5,10,20,50,100],
    'max_depth': [2,4,8,10,20] ,
        'class_weight':['balanced',None] ,
        'criterion':['entropy','gini']
    }
    
    estimator = GridSearchCV(rf, param_grid, verbose = 1, cv = 3, n_jobs=6,scoring=metrics.make_scorer( metrics.balanced_accuracy_score))
    
    # Split data
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

    # Grid Search of Model
    estimator.fit(X_train, y_train)
    
    
    # CLASSIFC
    classification_per = classification_metrics(y_test, estimator.predict(X_test))
    print('Classification Performance \n')
    [print(f'{key} : {value}') for key, value in classification_per.items()]
    print('---'*10)
    
    #AUC
    y_probas = estimator.predict_proba(X_test)
    skplt.metrics.plot_roc(y_test, y_probas)

    plt.show()
    
    return estimator.best_estimator_

# %% [markdown]
# ## 4.2 and 5.6

# %%
pH = 6.5

print('==='*20)
print('############ pH = {}############'.format(pH))
Xdata = acidoCEST_ML[['4.2','5.6']]
Ydata = acidoCEST_ML.pH
RF_two_freqs_65 = train_RFC(Xdata,Ydata, pH_cut_off= pH)
pd.DataFrame(RF_two_freqs_65.feature_importances_, index=Xdata.columns, columns=['Imp']).plot(kind='bar')

# %%
pH = 7.0

print('==='*20)
print('############ pH = {}############'.format(pH))
Xdata = acidoCEST_ML[['4.2','5.6']]
Ydata = acidoCEST_ML.pH
RF_two_freqs_70 = train_RFC(Xdata,Ydata, pH_cut_off= pH)
pd.DataFrame(RF_two_freqs_70.feature_importances_, index=Xdata.columns, columns=['Imp']).plot(kind='bar')

# %% [markdown]
# ## 4.2 and 5.6  and  non-CEST exp data

# %%
c = ['4.2','5.6'] + exper_cols
pH = 6.5

Xdata = acidoCEST_ML[c]
Ydata = acidoCEST_ML.pH

RF_two_freqs_and_exp65 = train_RFC(Xdata,Ydata, pH_cut_off= pH)
pd.DataFrame(RF_two_freqs_and_exp65.feature_importances_, index=Xdata.columns, columns=['Imp']).plot(kind='bar')

# %%
print(RF_two_freqs_and_exp65)

# %%
c = ['4.2','5.6'] + exper_cols
pH = 7.0

Xdata = acidoCEST_ML[c]
Ydata = acidoCEST_ML.pH

RF_two_freqs_and_exp70 = train_RFC(Xdata,Ydata, pH_cut_off= pH)
pd.DataFrame(RF_two_freqs_and_exp70.feature_importances_, index=Xdata.columns, columns=['Imp']).plot(kind='bar')

# %% [markdown]
# ## All sat freqs

# %%
pH = 6.5

Xdata = acidoCEST_ML.drop(exper_cols + ['pH'],axis=1)
Ydata = acidoCEST_ML.pH 

RF_all_freqs65 = train_RFC(Xdata,Ydata, pH_cut_off= pH)

_ , ax = plt.subplots(dpi=100, figsize=(14,8))
pd.DataFrame(RF_all_freqs65.feature_importances_, index=Xdata.columns, columns=['Imp']).plot(kind='bar',ax=ax)

# %%
pH = 7.0

Xdata = acidoCEST_ML.drop(exper_cols + ['pH'],axis=1)
Ydata = acidoCEST_ML.pH 

RF_all_freqs70 = train_RFC(Xdata,Ydata, pH_cut_off= pH)

_ , ax = plt.subplots(dpi=100, figsize=(14,8))
pd.DataFrame(RF_all_freqs70.feature_importances_, index=Xdata.columns, columns=['Imp']).plot(kind='bar',ax=ax)

# %% [markdown]
# ## All data

# %%
pH = 6.5

Xdata = acidoCEST_ML.drop(['pH'],axis=1)
Ydata = acidoCEST_ML.pH 

RF_all_data65 = train_RFC(Xdata,Ydata, pH_cut_off= pH)

_ , ax = plt.subplots(dpi=100, figsize=(14,8))
pd.DataFrame(RF_all_data65.feature_importances_, index=Xdata.columns, columns=['Imp']).plot(kind='bar',ax=ax)

# %%
pH = 7.0

Xdata = acidoCEST_ML.drop(['pH'],axis=1)
Ydata = acidoCEST_ML.pH 

RF_all_data70 = train_RFC(Xdata,Ydata, pH_cut_off= pH)

_ , ax = plt.subplots(dpi=100, figsize=(14,8))
pd.DataFrame(RF_all_data70.feature_importances_, index=Xdata.columns, columns=['Imp']).plot(kind='bar',ax=ax)

# %% [markdown]
# ## Seleted features

# %%
s1 = set(pd.DataFrame(RF_all_data65.feature_importances_, index=Xdata.columns, columns=['Imp']).sort_values('Imp',ascending=False).head(20).index)

s2 = set(pd.DataFrame(RF_all_data70.feature_importances_, index=Xdata.columns, columns=['Imp']).sort_values('Imp',ascending=False).head(20).index)

# %%
sel_f = list(s1.union(s1))
sel_f.sort()

# %%
print(sel_f)

# %%
len(sel_f)

# %%
pH = 6.5

Xdata = acidoCEST_ML[sel_f]
Ydata = acidoCEST_ML.pH 

RF_set_features_65 = train_RFC(Xdata,Ydata, pH_cut_off= pH)

_ , ax = plt.subplots(dpi=100, figsize=(14,8))
pd.DataFrame(RF_set_features_65.feature_importances_, index=Xdata.columns, columns=['Imp']).plot(kind='bar',ax=ax)

# %%
pH = 7.0

Xdata = acidoCEST_ML[sel_f]
Ydata = acidoCEST_ML.pH 

RF_set_features_70 = train_RFC(Xdata,Ydata, pH_cut_off= pH)

_ , ax = plt.subplots(dpi=100, figsize=(14,8))
pd.DataFrame(RF_set_features_70.feature_importances_, index=Xdata.columns, columns=['Imp']).plot(kind='bar',ax=ax)

# %%
plot_tree?

# %%
# %%capture
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

features = ['0.6 ppm', '1.8 ppm', '2 ppm', '2.2 ppm', '4.1 ppm', '4.2 ppm', '4.3 ppm', '4.4 ppm', '4.5ppm ', '4.6 ppm',
       '4.7 ppm', '4.8 ppm', '4.9 ppm', '5.0 ppm', '5.8 ppm', '5.9 ppm', 'B0', 'B1',
       'T1', 'T2']

tree=RF_set_features_70.estimators_[1]

classes = list( pd.Series(tree.classes_).replace([0,1],[' pH < 7', 'pH > 7']).values )

fig = plt.figure(dpi=500)
plot_tree( tree,  feature_names = features, class_names= classes,
          filled=True, impurity=False,  max_depth = 20, fontsize = 1, label='none', proportion =True,
          rounded=False);

plt.savefig('Tree_example_max_depth_020.png',bbox_inches='tight')
#plt.close()

# %% [markdown]
# ## Random

# %%
pH = 7
Ydata = acidoCEST_ML.pH

Xdata = pd.DataFrame( np.random.rand(Ydata.shape[0],10) )


random_X = train_RFC(Xdata,Ydata, pH_cut_off= pH)

_ , ax = plt.subplots(dpi=100, figsize=(14,8))
pd.DataFrame(random_X.feature_importances_, index=Xdata.columns, columns=['Imp']).plot(kind='bar',ax=ax)
